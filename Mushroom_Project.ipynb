# %%
# Importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the dataset
df=pd.read_csv('mushrooms.csv')

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %% [raw]
# Dataset has 8124 rows and 23 columns

# %%
df.size
# Out:
# 186852

# %% [raw]
# df.size returns the total number of elements in dataset

# %%
df.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %% [markdown]
# All columns in dataset are object variable

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# There are missing values in the dataset

# %%
df['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
df['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %% [markdown]
# class is out target variable as mentioned in problem where p stands for poisonous and e stands for edible.

# %%
# Pie chart for class variable
labels='Edible','Poisonous'
fig,ax=plt.subplots()
ax.pie(df['class'].value_counts(),labels=labels,autopct='%1.2f%%',shadow=True)
plt.show()

# %%
sn.countplot(df['class'])

# %% [markdown]
# All three classes are equally distributed so there is no class imbalanced.

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
sn.countplot(df['cap-shape'])

# %%
# Plotting count graph of every independent variable

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in df:
    if plotnumber<=25:
        ax=plt.subplot(5,5,plotnumber)
        sn.countplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber=plotnumber+1
plt.show()

# %% [raw]
# From the above observation we can say that feature like bruises,gill-attachment,gill-spacing,gill-size,stalk-shape,veil-type,
# ring_number all have less than two classes in it while all the features have more than two classes.

# %% [markdown]
# ### Encoding categorical data

# %%
# applying encoding method
encode=LabelEncoder() # creating instance of encoder
for i in df:
    df[i]=encode.fit_transform(df[i])    
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %% [raw]
# Now target variable has been converted into two values 0 and 1 where 1 represent poisinous and 0 represent edible.

# %%
df.dtypes
# Now all the features now converted from categorical into numerical data.
# Out:
# class                       int32
# cap-shape                   int32
# cap-surface                 int32
# cap-color                   int32
# bruises                     int32
# odor                        int32
# gill-attachment             int32
# gill-spacing                int32
# gill-size                   int32
# gill-color                  int32
# stalk-shape                 int32
# stalk-root                  int32
# stalk-surface-above-ring    int32
# stalk-surface-below-ring    int32
# stalk-color-above-ring      int32
# stalk-color-below-ring      int32
# veil-type                   int32
# veil-color                  int32
# ring-number                 int32
# ring-type                   int32
# spore-print-color           int32
# population                  int32
# habitat                     int32
# dtype: object

# %%
df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
cor=df.corr()

# %%
cor
# Finding the correlation between the features
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
fig, axis = plt.subplots(figsize=(16, 7))
sn.heatmap(cor,annot=True,linewidths=.5)

# %%
cor['class'].sort_values(ascending=False).head(10)
# Out:
# class                1.000000
# gill-size            0.540024
# population           0.298686
# habitat              0.217179
# cap-surface          0.178446
# spore-print-color    0.171961
# veil-color           0.145142
# gill-attachment      0.129200
# cap-shape            0.052951
# cap-color           -0.031384
# Name: class, dtype: float64

# %%
cor['class'].sort_values(ascending=True).head(23)
# Out:
# gill-color                 -0.530566
# bruises                    -0.501530
# ring-type                  -0.411771
# stalk-root                 -0.379361
# gill-spacing               -0.348387
# stalk-surface-above-ring   -0.334593
# stalk-surface-below-ring   -0.298801
# ring-number                -0.214366
# stalk-color-above-ring     -0.154003
# stalk-color-below-ring     -0.146730
# stalk-shape                -0.102019
# odor                       -0.093552
# cap-color                  -0.031384
# cap-shape                   0.052951
# gill-attachment             0.129200
# veil-color                  0.145142
# spore-print-color           0.171961
# cap-surface                 0.178446
# habitat                     0.217179
# population                  0.298686
# gill-size                   0.540024
# class                       1.000000
# veil-type                        NaN
# Name: class, dtype: float64

# %% [markdown]
#  1.gill-color,bruises,ring-type,stalk-root are among the lease correlated with class.
#  2.Gill_size,population is having strong correlation with the class.
#  3.veil-type has no correlation at all with target varible.(need to drop veil-type variable)

# %%
for i in df:
    print(df[i].unique())
# Out:
# [1 0]
# [5 0 4 2 3 1]
# [2 3 0 1]
# [4 9 8 3 2 5 0 7 1 6]
# [1 0]
# [6 0 3 5 2 1 8 7 4]
# [1 0]
# [0 1]
# [1 0]
# [ 4  5  2  7 10  3  9  1  0  8 11  6]
# [0 1]
# [3 2 1 4 0]
# [2 0 1 3]
# [2 0 3 1]
# [7 3 6 4 0 2 5 1 8]
# [7 6 3 0 4 2 8 5 1]
# [0]
# [2 0 1 3]
# [1 2 0]
# [4 0 2 1 3]
# [2 3 6 1 7 5 4 8 0]
# [3 2 0 4 5 1]
# [5 1 3 0 4 6 2]

# %%
y=df['class']
x=df.drop(['class','veil-type'],axis=1)

# %%
x
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             5            2          4        1     6                1
# 1             5            2          9        1     0                1
# 2             0            2          8        1     3                1
# 3             5            3          8        1     6                1
# 4             5            2          3        0     5                1
# 5             5            3          9        1     0                1
# 6             0            2          8        1     0                1
# 7             0            3          8        1     3                1
# 8             5            3          8        1     6                1
# 9             0            2          9        1     0                1
# 10            5            3          9        1     3                1
# 11            5            3          9        1     0                1
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
# 5       0
# 6       0
# 7       0
# 8       1
# 9       0
# 10      0
# 11      0
# 12      0
# 13      1
# 14      0
# 15      0
# 16      0
# 17      1
# 18      1
# 19      1
# 20      0
# 21      1
# 22      0
# 23      0
# 24      0
# 25      1
# 26      0
# 27      0
# 28      0
# 29      0
#        ..
# 8094    0
# 8095    1
# 8096    0
# 8097    1
# 8098    1
# 8099    0
# 8100    0
# 8101    1
# 8102    0
# 8103    0
# 8104    0
# 8105    0
# 8106    0
# 8107    0
# 8108    1
# 8109    0
# 8110    0
# 8111    0
# 8112    0
# 8113    1
# 8114    1
# 8115    0
# 8116    1
# 8117    1
# 8118    1
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ####  we can see that since it is categorical data we don't need to apply oultier and skewness technique.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %% [markdown]
# ### Finding best random state

# %%
from sklearn.linear_model import LogisticRegression
MaxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=i)
    mod=LogisticRegression()
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>MaxAccu:
        MaxAccu=acc
        maxRS=i
print("Best accuracy is",MaxAccu,'on radom state',maxRS)
# Out:
# Best accuracy is 0.9581624282198523 on radom state 21

# %% [markdown]
# ### Training and splitting the data

# %%
# Training and Splitting the data  
x_train,x_test,y_train,_y_test=train_test_split(x,y,test_size=0.3,random_state=21)
print(y_train)
# Out:
# 3478    0
# 6624    1
# 2899    0
# 7874    1
# 6667    1
# 7341    1
# 2075    0
# 177     0
# 6074    1
# 1196    0
# 3721    0
# 7690    1
# 1212    0
# 2634    0
# 4692    1
# 5059    1
# 2605    1
# 4650    1
# 2987    0
# 3080    0
# 6272    1
# 405     0
# 7277    1
# 7328    0
# 3252    0
# 2301    0
# 1523    0
# 7467    0
# 4269    1
# 3671    0
#        ..
# 6804    1
# 7483    1
# 2644    0
# 5094    1
# 2916    0
# 3310    0
# 2352    0
# 6266    1
# 7926    1
# 1789    0
# 233     0
# 7421    1
# 829     0
# 5548    1
# 447     0
# 1646    0
# 840     0
# 4298    1
# 6897    1
# 6655    1
# 4706    1
# 6844    1
# 7587    1
# 1144    0
# 6512    1
# 48      0
# 772     0
# 5944    1
# 5327    1
# 7113    1
# Name: class, Length: 5686, dtype: int64

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
# Using Logistic regression classification model
classifier=LogisticRegression()
classifier.fit(x_train,y_train)
pred=classifier.predict(x_test)
acc=classification_report(y_test,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.52      0.52      1257
#            1       0.49      0.48      0.48      1181
#
#    micro avg       0.50      0.50      0.50      2438
#    macro avg       0.50      0.50      0.50      2438
# weighted avg       0.50      0.50      0.50      2438

# %%
#Using Randome forest classifier
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier()
RF.fit(x_train,y_train)
pred=RF.predict(x_test)
acc=classification_report(y_test,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.51      0.51      1257
#            1       0.48      0.47      0.48      1181
#
#    micro avg       0.49      0.49      0.49      2438
#    macro avg       0.49      0.49      0.49      2438
# weighted avg       0.49      0.49      0.49      2438

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
pred=svc.predict(x_test)
acc=classification_report(y_test,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.51      0.51      1257
#            1       0.48      0.47      0.48      1181
#
#    micro avg       0.49      0.49      0.49      2438
#    macro avg       0.49      0.49      0.49      2438
# weighted avg       0.49      0.49      0.49      2438

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(classifier,x,y,cv=5).mean())
# Out:
# 0.8439478047846034

# %%
print(cross_val_score(RF,x,y,cv=5).mean())
# Out:
# 0.8981917912176469

# %%
print(cross_val_score(svc,x,y,cv=5).mean())
# Out:
# 0.8640868258178603

# %% [markdown]
# ### Saving the model

# %%
Final_mod2=RandomForestClassifier(criterion='gini',max_depth=5,max_features='auto',n_estimators=200)
Final_mod2.fit(x_train,y_train)
pred=Final_mod2.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 49.261689909762104

# %%
from sklearn.externals import joblib

# %%
joblib.dump(Final_mod2,'Final_Model2.pkl')
# Out:
# ['Final_Model2.pkl']
